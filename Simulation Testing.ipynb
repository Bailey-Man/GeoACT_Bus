# %%
import runpy
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib notebook
sys.path.insert(0, 'src')
from bus import bus_sim

# %%
# !python av_run.py -l 11.4 -t 30 -s "full" -n 56 -m 100 -w 6
bus_trip, conc_array, out_mat, chance_nonzero, avg_mat = bus_sim(56, 1, 100, 30, "full", 6) # replace default with selected
# windows OPEN
# Out:
# finis
# plot seating complete!
# ach 20
# airborne transmission rate 2.700225387237963e-05
# relative airflow complete!
# ach 20
# airborne transmission rate 2.700225387237963e-05
# model_run complete!
# av finish
# ach 20
# airborne transmission rate 2.700225387237963e-05
# C:\Users\Bailey\Desktop\Github files\GeoACT_Bus\av.py:216: UserWarning: FixedFormatter should only be used together with FixedLocator
#   plt.gca().set_xticklabels(['{:.1f}%'.format(x*100) for x in plt.gca().get_xticks()])

# %%
# pd.Series(out_mat).plot.hist(color='r', linewidth=2, edgecolor='k', bins=np.arange(0, 0.028, 0.0005), alpha=.5)
# plt.matshow(conc_array)
# len(bus_trip)
plt.matshow(conc_array[0])
plt.matshow(conc_array[4])
# find a way to show which is the adjacent student!
# Out:
# <img src="data:image/png;base64,..." width="399.99999403953564">
# <img src="data:image/png;base64,..." width="399.99999403953564">

# %%
# outputs: 1-8

# 1 trip risk hist

# 2 mask risk hist

# 3 seating risk hist

# 4 5 6 have 1 infected, 
# 1000 initializations to cover the initial sampling distribution
# 4 worst case heatmap

# 5 best case heatmap

# 6 selected params heatmap

# other
# 7 Plot infection likelihood vs distance from initially infected

# 8 return average # infections per run: # infected total / 10000 sims
